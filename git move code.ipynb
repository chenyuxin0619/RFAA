# %%
conda --version

# %%
conda info
# Out:
#      active environment : base
#     active env location : /Users/ldabuliedianxiaobawang/anaconda3
#             shell level : 1
#        user config file : /Users/ldabuliedianxiaobawang/.condarc
#  populated config files : /Users/ldabuliedianxiaobawang/.condarc
#           conda version : 23.9.0
#     conda-build version : 3.26.1
#          python version : 3.11.5.final.0
#        virtual packages : __archspec=1=arm64
#                           __osx=13.5=0
#                           __unix=0=0
#        base environment : /Users/ldabuliedianxiaobawang/anaconda3  (writable)
#       conda av data dir : /Users/ldabuliedianxiaobawang/anaconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-arm64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-arm64
#                           https://repo.anaconda.com/pkgs/r/noarch
# ...

# %%
# !git info
# Out:
# git: 'info' is not a git command. See 'git --help'.
#
# The most similar commands are
# 	init
# 	mailinfo

# %%
# !git --version
# Out:
# git version 2.40.1

# %%
conda install -c anaconda git
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# !$ conda update -n base -c defaults conda
# Out:
# zsh:1: command not found: $

# %%
# !git --version
# Out:
# git version 2.40.1

# %%
# !git config --global user.name "chenyuxin0619"
# !git config --global user.email "zcahy67@ucl.ac.uk"

# %%
# !git clone https://github.com/chenyuxin0619/RFAA.git
# Out:
# fatal: destination path 'RFAA' already exists and is not an empty directory.

# %%
# !git add .

# %%
# !git commit -m "Added week 2 code"
# Out:
# [master e3f195a] Added week 2 code
#  176 files changed, 106177 insertions(+), 861 deletions(-)
#  create mode 100644 .DS_Store
#  create mode 100644 .ipynb_checkpoints/Week 2-checkpoint.ipynb
#  create mode 100644 .ipynb_checkpoints/git move -checkpoint.ipynb
#  create mode 100644 .localized
#  create mode 100644 2023 Day 1 AM - 00 01+01 02+02 03+03 Slides.pdf
#  create mode 100644 BibliU-5-24 part1.pdf
#  create mode 100644 ClashX
#  create mode 100644 Coporate finance/.DS_Store
#  create mode 100644 Coporate finance/Day 1-20231005/2023 Day 1 AM - 00 01+01 02+02 03+03 Slides.docx
#  create mode 100644 Coporate finance/Day 1-20231005/2023 Day 1 AM - 00 01+01 02+02 03+03 Slides.pdf
#  create mode 100644 Coporate finance/Day 1-20231005/2023 Day 1 AM - 00 01+01 02+02 03+03 Slides.pptx
#  create mode 100644 Coporate finance/Day 1-20231005/2023 Day 1 AM - 02+02 Financial Statements - Ch02 Tool Kit.xlsx
# ...

# %%
pwd
# Out:
# '/Users/ldabuliedianxiaobawang/Desktop'

# %%
# !git rev-parse --show-toplevel
# Out:
# /Users/ldabuliedianxiaobawang/Desktop

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /Users/ldabuliedianxiaobawang/Desktop/.git/

# %%
# !git add week2 sus .ipynb
# Out:
# fatal: pathspec 'week2' did not match any files

# %%
# !git config core.precomposeunicode false

# %%
# !git add "sus.ipynb"
# Out:
# fatal: pathspec 'sus.ipynb' did not match any files

# %%
# !git commit -m "Added sus notebook"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
# !git push origin master
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
# !which git
# Out:
# /Users/ldabuliedianxiaobawang/anaconda3/bin/git

# %%
# !git clone https://github.com/chenyuxin0619/RFAA.git
cd RFAA
# Out:
#   Cell In[27], line 2
#     cd RFAA
#        ^
# SyntaxError: invalid syntax

# %%
# !git clone https://github.com/chenyuxin0619/RFAA.git
# Out:
# fatal: destination path 'RFAA' already exists and is not an empty directory.

# %%
cd /Users/ldabuliedianxiaobawang/Desktop/RFAA
# Out:
# /Users/ldabuliedianxiaobawang/Desktop/RFAA

# %%
# !git add sus.ipynb

# %%
# !git commit -m "Added my Jupyter notebook"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Username for 'https://github.com':

# %%
git log --oneline

# %%
# !git status
