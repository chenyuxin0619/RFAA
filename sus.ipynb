# %%
def square(x):
    return x * x
x = 3
y = square(x)
print('%d square is %d' % (x,y))
# Out:
# 3 square is 9

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,10,100)

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')

# %%
pip install yfinance
# Out:
# ...
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/e6/b3/388ab967a387cc92926f70e97688dd9a7189b29a0773db815ffc5289e2b5/yfinance-0.2.31-py2.py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 928.0/928.0 kB 10.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 7.7 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.16.3-py3-none-any.whl size=135501 sha256=6f91beb97e692d086b61bbec8cdbeed2436fccbce180af59e0086ee7002e20af
#   Stored in directory: /Users/ldabuliedianxiaobawang/Library/Caches/pip/wheels/71/3b/27/57acb9258fc0c3744c912061f8bb9a94dac6a27579a4e8a12b
# Successfully built peewee
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
initial_data = yf.download("AAPL AMZN META GOOG MSFT TSLA SPY ^VIX", start='2022-10-01', end='2023-10-01')
# Out:
# [*********************100%%**********************]  8 of 8 completed

# %%
initial_data.head()
# Out:
#              Adj Close                                                  \
#                   AAPL        AMZN        GOOG        META        MSFT
# Date
# 2022-10-03  141.609924  115.879997   99.300003  138.610001  238.436523
# 2022-10-04  145.238403  121.089996  102.410004  140.279999  246.498627
# 2022-10-05  145.536606  120.949997  102.220001  138.979996  246.815552
# 2022-10-06  144.572342  120.300003  102.239998  139.070007  244.428635
# 2022-10-07  139.263840  114.559998   99.570000  133.449997  231.998703
#
#                                                     Close              ...  \
#                    SPY        TSLA       ^VIX        AAPL        AMZN  ...
# Date                                                                   ...
# 2022-10-03  360.928192  242.399994  30.100000  142.449997  115.879997  ...
# 2022-10-04  372.112122  249.440002  29.070000  146.100006  121.089996  ...
# 2022-10-05  371.245728  240.809998  28.549999  146.399994  120.949997  ...
# ...

# %%
pip install yesg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for yesg: filename=yesg-2.1.1-py3-none-any.whl size=6104 sha256=49e5e1105b0bc5ea93d33cfac39176991e02df172b61c828c080db4a78a6e21e
#   Stored in directory: /Users/ldabuliedianxiaobawang/Library/Caches/pip/wheels/78/8d/48/f5e8ff0315a46301e15c68371e297b460b33e1c846117725bc
# Successfully built yesg
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yesg

# %%
ESG = yesg.get_historic_esg('AAPL')
ESG
# Out:
#             Total-Score  E-Score  S-Score  G-Score
# Date
# 2014-09-01        61.00    74.00    45.00    62.00
# 2014-10-01        60.00    74.00    45.00    62.00
# 2014-11-01        61.00    74.00    45.00    62.00
# 2014-12-01        61.00    74.00    45.00    62.00
# 2015-01-01        61.00    74.00    45.00    62.00
# ...                 ...      ...      ...      ...
# 2022-04-01          NaN      NaN      NaN      NaN
# 2022-05-01        16.41     0.65     6.86     8.90
# 2022-06-01          NaN      NaN      NaN      NaN
# 2022-07-01          NaN      NaN      NaN      NaN
# 2022-08-01        16.68     0.65     6.86     9.18
#
# [96 rows x 4 columns]

# %%
ESG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 96 entries, 2014-09-01 to 2022-08-01
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Total-Score  78 non-null     float64
#  1   E-Score      78 non-null     float64
#  2   S-Score      78 non-null     float64
#  3   G-Score      78 non-null     float64
# dtypes: float64(4)
# memory usage: 3.8 KB

# %%
ESG.new = pd.DataFrame.dropna(ESG)
ESG.new
# Out:
# /tmp/ipykernel_11418/2012856212.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   ESG.new = pd.DataFrame.dropna(ESG)
#             Total-Score  E-Score  S-Score  G-Score
# Date
# 2014-09-01        61.00    74.00    45.00    62.00
# 2014-10-01        60.00    74.00    45.00    62.00
# 2014-11-01        61.00    74.00    45.00    62.00
# 2014-12-01        61.00    74.00    45.00    62.00
# 2015-01-01        61.00    74.00    45.00    62.00
# ...                 ...      ...      ...      ...
# 2021-05-01        16.92     0.29     7.69     8.94
# 2021-09-01        16.92     0.29     7.99     8.64
# 2022-02-01        16.27     0.65     6.86     8.76
# 2022-05-01        16.41     0.65     6.86     8.90
# 2022-08-01        16.68     0.65     6.86     9.18
#
# [78 rows x 4 columns]

# %%
import pandas as pd

# %%
ESG.plot(figsize=(10, 6))
plt.xlabel('Time')
plt.ylabel('score')
plt.title('ESG for Apple Inc.')
# Out:
# Text(0.5, 1.0, 'ESG for Apple Inc.')
